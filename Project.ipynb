# %%
# Tic-Tac-Toe Game
import random
m=[[" "," "," "],[" "," "," "],[" "," "," "]]
a=input("Enter the type of input, i.e, 'X' or 'O': ")
n=len(m)
for i in range(n):
    print(m[i])
comp=[]
user=[]
if a=="X":
    c="O"
else:
    c="X"

for x in range(5):
    temp=[]
    p=int(input("Enter position of x in format (x,y): "))
    q=int(input("Enter position of y in format (x,y): "))
    s,t=random.randint(0,2),random.randint(0,2)
    while (p==s and q==t) or ([s,t] in comp):
        if len(comp)==8:
            break
        s,t=random.randint(0,2),random.randint(0,2)
    user.append([p,q])
    comp.append([p,q])
    temp=[]
    comp.append([s,t])
    for i in range(n):
        print("-----------------")
        for j in range(n):
            print(end="|")
            if i==p and j==q:
                m[i][j]=a
            elif i==s and j==t:
                m[i][j]=c
            print("",m[i][j], end=" | ")
        print()
    print("-----------------")
    print(comp)
#Result
#Diagonal1
    if m[0][0]==m[1][1]==m[2][2] and m[0][0]!=" ":
        if m[0][0]==a:
            print("User Won")
            break
        else:
            print("Computer Won")
            break
#Diagonal2
    elif m[0][2]==m[2][0]==m[1][1] and m[0][2]!=" ":
        if m[0][2]==a:
            print("User Won")
            break
        else:
            print("Computer Won")
            break
#Rowwise
    flag= True
    for i in range(len(m)):
        val=[]
        for j in range(len(m)):
            val.append(m[i][j])
        if val[0]==val[1]==val[2]:
            if val[0]==a:
                print("User won")
                flag= False
                break
            elif val[0]==c:
                print("Computer won")
                Flag= False
                break
        if flag is False:
            break
    if flag is False:
        break
#Columnwise
    flag= True
    for i in range(len(m)):
        if m[i][0]==m[i][0]==m[i][0]:
            if m[0]==a:
                print("User won")
                flag= False
                break
            elif m[0]==c:
                print("Computer won")
                Flag= False
                break
        if m[i][1]==m[i][1]==m[i][1]:
            if m[0]==a:
                print("User won")
                flag= False
                break
            elif m[0]==c:
                print("Computer won")
                Flag= False
                break
        if m[i][2]==m[i][2]==m[i][2]:
            if m[0]==a:
                print("User won")
                flag= False
                break
            elif m[0]==c:
                print("Computer won")
                Flag= False
                break
        if flag is False:
            break
    if flag is False:
        break

# %%
import random
N=int(input("How many times you want to play: "))
m=["Rock", "Paper", "Scissor"]
t=0
uw=0
cw=0

for i in range(N):
    user=input("Enter your input: ")
    c=random.randint(0,2)
    comp=m[c]
    print("Computer choose:",comp)
    if comp==user:
        print("Match Tie")
        t+=1
    elif user=="Rock":
        if comp=="Scissor":
            print("User won")
            uw+=1
        elif comp=="Paper":
            print("Computer won")
            cw+=1
    elif user=="Paper":
        if comp=="Rock":
            print("User won")
            uw+=1
        elif comp=="Scissor":
            print("Computer won")
            cw+=1
    elif user=="Scissor":
        if comp=="Rock":
            print("Computer won")
            cw+=1
        elif comp=="Paper":
            print("User won")
            uw+=1
if uw==cw:
    print("The match is tie")
elif uw>cw:
    print("The user won the match by ratio {}:{}".format(uw,cw))
elif cw>uw:
    print("The  computer won the match by ratio {}:{}".format(uw,cw))
# Out:
# How many times you want to play: 2
# Enter your input: Rock
# Computer choose: Scissor
# User won
# Enter your input: Rock
# Computer choose: Rock
# Match Tie
# The user won the match by ratio 1:0

# %%
#2048
import random
m=[0*4]*4
while True:
    for i in m:
        print(i)
    print("Enter 'w' for up, 'a' for left, 'd' for right, 's' for down")
    a=input()
    if a=="w":
        for i in range(len(m)):
            for j in range(len(m)):

# %%
# Cafeteria Management System
li=[]
print("The Menu is \n 1 Samosa Rs.15 \n 1 Tea Rs.10 \n 1 Spring Roll Rs.99 \n 1 Pav Bhaji Rs.109 \n 1 Oreo Shake Rs.50")
def price(it,qty):
    if it=="s":
        return qty*15
    elif it=="t":
        return qty*10
    elif it=="sr":
        return qty*99
    elif it=="p":
        return qty*109
    elif it=="o":
        return qty*50
def order():
    for k in range(1):
        it=input("Type 's' for samosa, 't' for tea, 'sr' for spring roll, 'p' for pav bhaji, 'o' for oreo shake: \n")
        qty=int(input("Enter the quantity of the order: "))
        p=price(it,qty)
        if it=="s":
            it="Samosa"
        elif it=="t":
            it="Tea"
        elif it=="sr":
            it="Spring Roll"
        elif it=="p":
            it="Pav Bhaji"
        elif it=="o":
            it="Oreo Shake"
        li.append([it,qty,p])
        while True:
            t=int(input("Type \n '1' for ordering anything else \n '2' for starting over \n '3' for removing a item \n '4' for billing \n '5' for reviewing the order list: \n"))
            if t==1:
                it=input("Type 's' for samosa, 't' for tea, 'sr' for spring roll, 'p' for pav bhaji, 'o' for oreo shake: \n")
                qty=int(input("Enter the quantity of the order: "))
                p=price(it,qty)
                if it=="s":
                    it="Samosa"
                elif it=="t":
                    it="Tea"
                elif it=="sr":
                    it="Spring Roll"
                elif it=="p":
                    it="Pav Bhaji"
                elif it=="o":
                    it="Oreo Shake"
                li.append([it,qty,p])
            if t==2:
                li.clear()
                order()
                break
            if t==3:
                r=input("Type 's' for samosa, 't' for tea, 'sr' for spring roll, 'p' for pav bhaji, 'o' for oreo shake: \n")
                if r=="s":
                    r="Samosa"
                elif r=="t":
                    r="Tea"
                elif r=="sr":
                    r="Spring Roll"
                elif r=="p":
                    r="Pav Bhaji"
                elif r=="o":
                    r="Oreo Shake"
                flag= False
                for i in range(len(li)):
                    for j in range(2):
                        if r==li[i][j]:
                            li.remove(li[i])
                            flag= True
                            break
                    if flag is True:
                        break
            if t==4:
                break
            if t==5:
                print("Your Bill is:\n[Order Name, Quantity, Total Price]")
                for i in range(len(li)):
                    print(li[i])

order()

print("Your Bill is:\n[Order Name, Quantity, Total Price]")

for i in range(len(li)):
    print(li[i])

sum=0
for i in range(len(li)):
    sum+=li[i][2]
print("Total Rs.{}".format(sum))
# Out:
# The Menu is
#  1 Samosa Rs.15
#  1 Tea Rs.10
#  1 Spring Roll Rs.99
#  1 Pav Bhaji Rs.109
#  1 Oreo Shake Rs.50
# Type 's' for samosa, 't' for tea, 'sr' for spring roll, 'p' for pav bhaji, 'o' for oreo shake:
# s
# Enter the quantity of the order: 2
# Type
#  '1' for ordering anything else
#  '2' for starting over
#  '3' for removing a item
#  '4' for billing
#  '5' for reviewing the order list:
# 1
# Type 's' for samosa, 't' for tea, 'sr' for spring roll, 'p' for pav bhaji, 'o' for oreo shake:
# t
# Enter the quantity of the order: 2
# Type
#  '1' for ordering anything else
#  '2' for starting over
#  '3' for removing a item
#  '4' for billing
#  '5' for reviewing the order list:
# 4
# Your Bill is:
# [Order Name, Quantity, Total Price]
# ['Samosa', 2, 30]
# ['Tea', 2, 20]
# Total Rs.50
